# %%
import networkx as nx 
import matplotlib.pyplot as plt
G=nx.DiGraph() 

G.add_edge('UU Nomor 4 Tahun 2011','UUD 1945') 

G.add_edge('UU Nomor 9 Tahun 1998','UUD 1945') 

G.add_edge('UU Nomor 21 Tahun 2013','UUD 1945') 

G.add_edge('UU Nomor 33 Tahun 2009','UUD 1945') 

G.add_edge('UU Nomor 40 Tahun 2007','UUD 1945') 

G.add_edge('UU Nomor 41 Tahun 1999','UUD 1945') 
G.add_edge('UU Nomor 41 Tahun 1999','Ketetapan MPR Nomor XV/MPR/1998')
G.add_edge('UU Nomor 41 Tahun 1999','UU Nomor 5 Tahun 1960')
G.add_edge('UU Nomor 41 Tahun 1999','UU Nomor 5 Tahun 1999')
G.add_edge('UU Nomor 41 Tahun 1999','UU Nomor 24 Tahun 1992')
G.add_edge('UU Nomor 41 Tahun 1999','UU Nomor 23 Tahun 1997')
G.add_edge('UU Nomor 41 Tahun 1999','UU Nomor 22 Tahun 1999')

G.add_edge('UU Nomor 45 Tahun 2009','UUD 1945')

G.add_edge('UU Nomor 58 Tahun 2014','UUD 1945')
G.add_edge('UU Nomor 58 Tahun 2014','UU Nomor Tahun 2009')

G.add_edge('UU Nomor 16 Tahun 2001','UUD 1945')

G.add_edge('UU Nomor 6 Tahun 2014','UUD 1945')

nx.draw_networkx(G)
plt.axis('off')
plt.show() # display
